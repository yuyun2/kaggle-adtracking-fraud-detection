# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import KFold

# %matplotlib inline

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv('./data/train_sample.csv', low_memory=False, parse_dates=['click_time', 'attributed_time'])
test = pd.read_csv('./data/test.csv', low_memory=False, parse_dates=['click_time'])

# %%
data['is_train'] = 1
test['is_train'] = 0

# %%
dups = data[data[['ip','click_time']].duplicated()]

# %%
dups.shape
# Out:
# (23, 8)

# %%
data.loc[(data['ip'].isin(dups['ip'])) & (data['click_time'].isin(dups['click_time']))]\
    .sort_values(by=['ip','click_time'])
# Out:
#            ip  app  device  os  channel          click_time attributed_time  \
# 64362     871   12       1  13      178 2017-11-08 10:00:05             NaT
# 84125     871   12       1  13      178 2017-11-08 10:00:05             NaT
# 40703    5314   18       1  37      379 2017-11-09 15:13:53             NaT
# 75203    5314   26       2  13      121 2017-11-09 15:13:53             NaT
# 23543    9801    9       1  11      134 2017-11-06 22:17:34             NaT
# 36094    9801    8       1  11      145 2017-11-06 22:17:34             NaT
# 8423    24008    1       2  20      125 2017-11-08 13:01:16             NaT
# 22844   24008   24       2  20      178 2017-11-08 13:01:16             NaT
# 42077   26995    1       1  49      124 2017-11-08 11:31:59             NaT
# 73851   26995   12       2  13      265 2017-11-08 11:31:59             NaT
# 27497   33617    8       1  19      145 2017-11-09 04:45:46             NaT
# 38688   33617    9       1  19      232 2017-11-09 04:45:46             NaT
# 41216   38866    8       1  47      140 2017-11-09 01:01:59             NaT
# 98658   38866    9       1  47      215 2017-11-09 01:01:59             NaT
# 20471   52628    2       1  19      469 2017-11-09 12:41:35             NaT
# 54313   52628   14       1  19      349 2017-11-09 12:41:35             NaT
# 108     61667    8       2  97      259 2017-11-07 05:00:39             NaT
# 68960   61667   20       2  97      259 2017-11-07 05:00:39             NaT
# 13743   66824    3       1   6      115 2017-11-08 05:12:19             NaT
# 85668   66824    3       1   6      417 2017-11-08 05:12:19             NaT
# 18596   77048    3       1  27      137 2017-11-08 00:39:14             NaT
# 32127   77048   15       1  27      245 2017-11-08 00:39:14             NaT
# 43033   92735    9       2  19      258 2017-11-09 12:19:30             NaT
# 95535   92735   12       2  19      145 2017-11-09 12:19:30             NaT
# 32968   98045    8       1  19      145 2017-11-07 14:27:31             NaT
# 47825   98045    1       1  19      134 2017-11-07 14:27:31             NaT
# 11106  103463    9       1  19      445 2017-11-09 14:20:15             NaT
# 49546  103463    3       1  19      417 2017-11-09 14:20:15             NaT
# 18184  111025    9       2  19      445 2017-11-08 15:19:34             NaT
# 41923  111025   20       1  19      478 2017-11-08 15:19:34             NaT
# 13229  123375    2       1  13      377 2017-11-09 08:35:33             NaT
# 19895  123375   14       1  13      379 2017-11-09 08:35:33             NaT
# 37297  132006   15       1  11      278 2017-11-07 02:00:55             NaT
# 37356  132006   14       1  11      489 2017-11-07 02:00:55             NaT
# 14502  141432    3       1  19      115 2017-11-08 17:09:52             NaT
# 32123  141432    3       1  19      452 2017-11-08 17:09:52             NaT
# 4986   142366   21       1  28      232 2017-11-09 09:58:41             NaT
# 40937  142366    9       1  28      448 2017-11-09 09:58:41             NaT
# 32672  166519   12       1  18      265 2017-11-07 01:21:11             NaT
# 99022  166519   64       1  18      459 2017-11-07 01:21:11             NaT
# 34193  184859    2       1   8      469 2017-11-08 01:53:27             NaT
# 94429  184859   14       1   8      439 2017-11-08 01:53:27             NaT
# 8560   313039    3       1  18      135 2017-11-09 15:52:09             NaT
# 9170   313039   25       1  18      259 2017-11-09 15:52:09             NaT
# 2573   313289    9       1  19      442 2017-11-09 12:24:26             NaT
# 20830  313289    2       1  19      258 2017-11-09 12:24:26             NaT
#
#        is_attributed
# 64362              0
# 84125              0
# 40703              0
# 75203              0
# 23543              0
# 36094              0
# 8423               0
# 22844              0
# 42077              0
# 73851              0
# 27497              0
# 38688              0
# 41216              0
# 98658              0
# 20471              0
# 54313              0
# 108                0
# 68960              0
# 13743              0
# 85668              0
# 18596              0
# 32127              0
# 43033              0
# 95535              0
# 32968              0
# 47825              0
# 11106              0
# 49546              0
# 18184              0
# 41923              0
# 13229              0
# 19895              0
# 37297              0
# 37356              0
# 14502              0
# 32123              0
# 4986               0
# 40937              0
# 32672              0
# 99022              0
# 34193              0
# 94429              0
# 8560               0
# 9170               0
# 2573               0
# 20830              0

# %%
data.loc[(data['ip']==871)]
# Out:
#         ip  app  device   os  channel          click_time attributed_time  \
# 27486  871   15       1   10      430 2017-11-07 00:44:01             NaT
# 33669  871    9       1   37      244 2017-11-08 09:57:37             NaT
# 40335  871   15       2   15        3 2017-11-07 16:12:12             NaT
# 56614  871   18       1  607      107 2017-11-06 21:16:26             NaT
# 64362  871   12       1   13      178 2017-11-08 10:00:05             NaT
# 74907  871    3       1   16      280 2017-11-07 00:57:22             NaT
# 83643  871   11       1   18      319 2017-11-07 08:06:07             NaT
# 84125  871   12       1   13      178 2017-11-08 10:00:05             NaT
#
#        is_attributed
# 27486              0
# 33669              0
# 40335              0
# 56614              0
# 64362              0
# 74907              0
# 83643              0
# 84125              0

# %%
data[['ip', 'click_time']].drop_duplicates().shape
# Out:
# (99977, 2)

# %%
full_data = pd.concat([data, test], axis=0)

# %%
full_data.head()
# Out:
#    app attributed_time  channel  click_id          click_time  device      ip  \
# 0   12             NaT      497       NaN 2017-11-07 09:30:38       1   87540
# 1   25             NaT      259       NaN 2017-11-07 13:40:27       1  105560
# 2   12             NaT      212       NaN 2017-11-07 18:05:24       1  101424
# 3   13             NaT      477       NaN 2017-11-07 04:58:08       1   94584
# 4   12             NaT      178       NaN 2017-11-09 09:00:09       1   68413
#
#    is_attributed  is_train  os
# 0            0.0         1  13
# 1            0.0         1  17
# 2            0.0         1  19
# 3            0.0         1  13
# 4            0.0         1   1

# %%
sub_data = pd.read_csv('./data/train_sample.csv', low_memory=False, parse_dates=['click_time'], 
                      nrows = 10000, usecols=['ip', 'click_time'])

# %%
sub_data.to_csv('sub_data.csv', index=False)

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# There are many ways to generate useful features. We introduce following technique in generating features.

# %% [markdown]
# #### Extract Useful Time Information

# %%
def date_part(data,fld_name,f_mat):
    prefix='dt'
    date_time = data[fld_name]
    fld = pd.to_datetime(date_time, format=f_mat)
    for n in ('hour', 'minute'):
        data[prefix+'_'+n] = getattr(fld.dt,n.lower())

# %%
date_part(data, 'click_time', f_mat='%d%b%Y:%H:%M:%S.%f')

# %%
date_part(test, 'click_time', f_mat='%d%b%Y:%H:%M:%S.%f')

# %%
data.head()
# Out:
#        ip  app  device  os  channel          click_time attributed_time  \
# 0   87540   12       1  13      497 2017-11-07 09:30:38             NaT
# 1  105560   25       1  17      259 2017-11-07 13:40:27             NaT
# 2  101424   12       1  19      212 2017-11-07 18:05:24             NaT
# 3   94584   13       1  13      477 2017-11-07 04:58:08             NaT
# 4   68413   12       1   1      178 2017-11-09 09:00:09             NaT
#
#    is_attributed  dt_hour  dt_minute
# 0              0        9         30
# 1              0       13         40
# 2              0       18          5
# 3              0        4         58
# 4              0        9          0

# %% [markdown]
# ### Mean Encoding

# %%
def reg_target_encoding(train, col ,target , splits=5):
    """ Computes regularize mean encoding.
    Inputs:
       train: training dataframe
       
    """
    kf = KFold(n_splits=splits,shuffle=False)
    train[col+'_mean_enc']=np.nan
    for train_index, val_index in kf.split(train[col].values):
        x_train,x_val = train.loc[train_index],train.loc[val_index]
        mean_device_type = x_train.groupby(col)[target].mean()
        x_val[col+'_mean_enc']=x_val[col].map(mean_device_type)
        train.loc[val_index]=x_val
    global_mean = train[col+'_mean_enc'].mean()
    train.fillna(global_mean,inplace=True)
    
def mean_encoding_test(test, train, col, target):
    """ Computes target enconding for test data.
    
    This is similar to how we do validation
    """
    # YOUR CODE HERE
    mean_encoded_value = train.groupby(col)[target].mean()
    
    global_mean = train[target].mean()
    
    test[col+'_mean_enc'] = test[col].map(mean_encoded_value)
    test[col+'_mean_enc'].fillna(global_mean, inplace=True)

# %%
def mean_encoding(train, test, cols, target):
    """ Computes target enconding for test data.
    
    This is similar to how we do validation
    """
    global_mean = train[target].mean()
    for col in cols:
        mean_encoded_value = train.groupby(col)[target].mean()
        train[col+'_mean_enc'] = train[col].map(mean_encoded_value)
        test[col+'_mean_enc'] = test[col].map(mean_encoded_value)
        test[col+'_mean_enc'].fillna(global_mean, inplace=True)

# %%
cols =['app', 'device', 'os', 'channel', 'dt_hour']
mean_encoding(data, test, cols, 'is_attributed')

# %%
data.head()
# Out:
#        ip  app  device  os  channel          click_time attributed_time  \
# 0   87540   12       1  13      497 2017-11-07 09:30:38             NaT
# 1  105560   25       1  17      259 2017-11-07 13:40:27             NaT
# 2  101424   12       1  19      212 2017-11-07 18:05:24             NaT
# 3   94584   13       1  13      477 2017-11-07 04:58:08             NaT
# 4   68413   12       1   1      178 2017-11-09 09:00:09             NaT
#
#    is_attributed  dt_hour  dt_minute  app_mean_enc  device_mean_enc  \
# 0              0        9         30      0.000076         0.001548
# 1              0       13         40      0.000000         0.001548
# 2              0       18          5      0.000076         0.001548
# 3              0        4         58      0.000000         0.001548
# 4              0        9          0      0.000076         0.001548
#
#    os_mean_enc  channel_mean_enc  dt_hour_mean_enc
# 0     0.001178               0.0          0.002055
# 1     0.001147               0.0          0.001780
# 2     0.001718               0.0          0.001691
# 3     0.001178               0.0          0.001656
# 4     0.000844               0.0          0.002055

# %%
test.head()
# Out:
#    click_id      ip  app  device  os  channel          click_time  dt_hour  \
# 0         0    5744    9       1   3      107 2017-11-10 04:00:00        4
# 1         1  119901    9       1   3      466 2017-11-10 04:00:00        4
# 2         2   72287   21       1  19      128 2017-11-10 04:00:00        4
# 3         3   78477   15       1  13      111 2017-11-10 04:00:00        4
# 4         4  123080   12       1  13      328 2017-11-10 04:00:00        4
#
#    dt_minute  app_mean_enc  device_mean_enc  os_mean_enc  channel_mean_enc  \
# 0          0      0.000890         0.001548     0.000635          0.000220
# 1          0      0.000890         0.001548     0.000635          0.001349
# 2          0      0.000000         0.001548     0.001718          0.000000
# 3          0      0.000233         0.001548     0.001178          0.000000
# 4          0      0.000076         0.001548     0.001178          0.000000
#
#    dt_hour_mean_enc
# 0          0.001656
# 1          0.001656
# 2          0.001656
# 3          0.001656
# 4          0.001656

# %% [markdown]
# ### Count Click

# %% [markdown]
# The idea is to calculate how many times a ip showed up before its given click time. The time difference between a ip of given click time since this ip appeared the vert firt time and this ip appeared right before the givin click time.

# %%
merge_ip = train[['ip','click_time']].merge(train[['ip', 'click_time']], 
                                                  on = 'ip', how = 'left', suffixes=('_l', '_r'))

# %%
merge_ip.head()
# Out:
#       ip        click_time_l        click_time_r
# 0  87540 2017-11-07 09:30:38 2017-11-07 09:30:38
# 1  87540 2017-11-07 09:30:38 2017-11-07 02:36:18
# 2  87540 2017-11-07 09:30:38 2017-11-07 01:52:35
# 3  87540 2017-11-07 09:30:38 2017-11-09 05:11:14
# 4  87540 2017-11-07 09:30:38 2017-11-07 10:14:34

# %%
data.shape
# Out:
# (100000, 8)

# %%
merge_ip.shape
# Out:
# (2541818, 3)

# %%
agg = merge_ip.loc[(merge_ip['click_time_l'] > merge_ip['click_time_r'])]\
              .groupby(['ip','click_time_l'])\
              .agg({'click_time_r':['count','min','max']})\
              .reset_index(col_level=1)

# %%
agg.columns = agg.columns.droplevel()

# %%
agg.head()
# Out:
#    ip        click_time_l  count                 min                 max
# 0  10 2017-11-07 07:33:04      1 2017-11-07 01:37:19 2017-11-07 01:37:19
# 1  10 2017-11-08 11:19:15      2 2017-11-07 01:37:19 2017-11-07 07:33:04
# 2  20 2017-11-08 03:06:02      1 2017-11-08 00:27:27 2017-11-08 00:27:27
# 3  20 2017-11-08 08:13:41      2 2017-11-08 00:27:27 2017-11-08 03:06:02
# 4  20 2017-11-09 03:46:51      3 2017-11-08 00:27:27 2017-11-08 08:13:41

# %%
agg['time_diff_ip_first'] = (agg['click_time_l'] - agg['min']).astype('timedelta64[s]') / 60.0
agg['time_diff_ip_last'] = (agg['click_time_l'] - agg['max']).astype('timedelta64[s]') / 60.0

# %%
agg.rename(columns = {'count':'cnt_ip_click'}, inplace=True)

# %%
data = data.merge(agg[['ip', 'click_time_l', 'cnt_ip_click', 'time_diff_ip_first', 'time_diff_ip_last']], 
                    left_on = ['ip', 'click_time'], right_on = ['ip', 'click_time_l'], how = 'left')

# %%
data.head()
# Out:
#        ip  app  device  os  channel          click_time attributed_time  \
# 0   87540   12       1  13      497 2017-11-07 09:30:38             NaT
# 1  105560   25       1  17      259 2017-11-07 13:40:27             NaT
# 2  101424   12       1  19      212 2017-11-07 18:05:24             NaT
# 3   94584   13       1  13      477 2017-11-07 04:58:08             NaT
# 4   68413   12       1   1      178 2017-11-09 09:00:09             NaT
#
#    is_attributed  dt_hour  dt_minute  app_mean_enc  device_mean_enc  \
# 0              0        9         30      0.000076         0.001548
# 1              0       13         40      0.000000         0.001548
# 2              0       18          5      0.000076         0.001548
# 3              0        4         58      0.000000         0.001548
# 4              0        9          0      0.000076         0.001548
#
#    os_mean_enc  channel_mean_enc  dt_hour_mean_enc        click_time_l  \
# 0     0.001178               0.0          0.002055 2017-11-07 09:30:38
# 1     0.001147               0.0          0.001780 2017-11-07 13:40:27
# 2     0.001718               0.0          0.001691                 NaT
# 3     0.001178               0.0          0.001656 2017-11-07 04:58:08
# 4     0.000844               0.0          0.002055 2017-11-09 09:00:09
#
#    cnt_ip_click  time_diff_ip_first  time_diff_ip_last
# 0           3.0          458.050000         245.083333
# 1          41.0         1298.466667          24.066667
# 2           NaN                 NaN                NaN
# 3           1.0          316.733333         316.733333
# 4           3.0         2761.350000         550.583333

# %% [markdown]
# ### possible new features

# %%
data.groupby(['ip', 'click_time'])['app'].count().reset_index().sort_values('app',ascending=False)
# Out:
#            ip          click_time  app
# 14953   24008 2017-11-08 13:01:16    2
# 70637  111025 2017-11-08 15:19:34    2
# 48384   77048 2017-11-08 00:39:14    2
# 23860   38866 2017-11-09 01:01:59    2
# 65447  103463 2017-11-09 14:20:15    2
# 16719   26995 2017-11-08 11:31:59    2
# 89218  184859 2017-11-08 01:53:27    2
# 38583   61667 2017-11-07 05:00:39    2
# 98478  313289 2017-11-09 12:24:26    2
# 82531  141432 2017-11-08 17:09:52    2
# 80964  132006 2017-11-07 02:00:55    2
# 20433   33617 2017-11-09 04:45:46    2
# 57828   92735 2017-11-09 12:19:30    2
# 41313   66824 2017-11-08 05:12:19    2
# 310       871 2017-11-08 10:00:05    2
# 7520     9801 2017-11-06 22:17:34    2
# 3928     5314 2017-11-09 15:13:53    2
# 98468  313039 2017-11-09 15:52:09    2
# 61511   98045 2017-11-07 14:27:31    2
# 78117  123375 2017-11-09 08:35:33    2
# 33422   52628 2017-11-09 12:41:35    2
# 82694  142366 2017-11-09 09:58:41    2
# 86392  166519 2017-11-07 01:21:11    2
# 66654  105475 2017-11-07 13:16:03    1
# 66651  105475 2017-11-07 12:25:25    1
# 66655  105475 2017-11-07 13:46:52    1
# 66652  105475 2017-11-07 12:28:52    1
# 66653  105475 2017-11-07 12:51:16    1
# 66657  105475 2017-11-07 14:27:26    1
# 66650  105475 2017-11-07 12:23:00    1
# ...       ...                 ...  ...
# 33303   52383 2017-11-08 01:29:30    1
# 33302   52383 2017-11-07 05:18:22    1
# 33301   52381 2017-11-07 04:38:16    1
# 33300   52370 2017-11-09 11:32:38    1
# 33299   52336 2017-11-07 07:19:04    1
# 33319   52422 2017-11-08 00:26:52    1
# 33321   52424 2017-11-07 05:28:30    1
# 33343   52465 2017-11-09 13:30:56    1
# 33333   52443 2017-11-09 12:20:22    1
# 33342   52464 2017-11-08 12:06:56    1
# 33341   52458 2017-11-08 14:36:45    1
# 33340   52458 2017-11-08 13:07:02    1
# 33339   52458 2017-11-08 11:58:04    1
# 33338   52457 2017-11-08 23:35:22    1
# 33337   52454 2017-11-08 01:35:34    1
# 33336   52452 2017-11-08 15:25:47    1
# 33335   52452 2017-11-07 22:51:45    1
# 33334   52452 2017-11-07 20:27:02    1
# 33332   52443 2017-11-07 09:00:18    1
# 33322   52432 2017-11-07 02:11:14    1
# 33331   52443 2017-11-07 01:39:15    1
# 33330   52443 2017-11-07 01:06:27    1
# 33329   52432 2017-11-09 03:15:28    1
# 33328   52432 2017-11-09 03:12:38    1
# 33327   52432 2017-11-09 02:08:26    1
# 33326   52432 2017-11-08 20:47:54    1
# 33325   52432 2017-11-08 13:38:04    1
# 33324   52432 2017-11-08 08:26:01    1
# 33323   52432 2017-11-07 17:22:52    1
# 99976  364757 2017-11-08 16:02:16    1
#
# [99977 rows x 3 columns]

# %% [markdown]
# ## Random Forest Model

# %%
features = ['app','device', 'os', 'channel', 'dt_hour', 'cnt_ip_click', 'time_diff_ip_first', 'time_diff_ip_last']
label = 'is_attributed'

# %%
X = data[features]
y = data[label]
test_X = test[features]

# %%
test_X.isnull().sum()
# Out:
# app                 0
# device              0
# os                  0
# channel             0
# dt_hour             0
# app_mean_enc        0
# device_mean_enc     0
# os_mean_enc         0
# channel_mean_enc    0
# dt_hour_mean_enc    0
# dtype: int64

# %%
test_X.shape[0]
# Out:
# 18790469

# %%
rf = RandomForestClassifier(n_estimators = 100, min_samples_leaf=50) # define Random Forest with 100 trees and 50 or more samples on each leaf node 
rf.fit(X,y)                                                          # train rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=50, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred_rf = rf.predict_proba(test_X)[:,1]

# %%
sample = pd.read_csv('./data/sample_submission.csv')

# %%
sample['is_attributed'] = y_pred_rf
sample.to_csv('sub_5_rf.csv', index=False)
